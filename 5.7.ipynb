# %%
import pandas as pd
import re

# %%
doc = "Web_access_log-akumenius.com.txt"

# %%
# Open log registry with a regex that separates all 
# data categories into different columns

ds = pd.read_csv(doc, 
                 sep = r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])', 
                 engine='python',
                 na_values='-',
                 usecols=[0, 1, 4, 5, 6, 7, 8, 9],
                 header=None,
                 names=['server', 'ip', 'time', 'request', 'status', 'size', 'referer', 'user_agent'],
                )

# %%
ds.tail(10)
# Out:
#                    server             ip                          time  \
# 261863      akumenius.com   5.255.253.53  [02/Mar/2014:03:05:32 +0100]
# 261864       akumenius.es   5.255.253.53  [02/Mar/2014:03:05:33 +0100]
# 261865      akumenius.com   5.255.253.53  [02/Mar/2014:03:05:35 +0100]
# 261866  www.akumenius.com   5.255.253.53  [02/Mar/2014:03:05:34 +0100]
# 261867       akumenius.es   5.255.253.53  [02/Mar/2014:03:05:35 +0100]
# 261868  www.akumenius.com   5.255.253.53  [02/Mar/2014:03:05:39 +0100]
# 261869  www.akumenius.com  74.86.158.107  [02/Mar/2014:03:09:52 +0100]
# 261870          localhost      127.0.0.1  [02/Mar/2014:03:10:18 +0100]
# 261871          localhost      127.0.0.1  [02/Mar/2014:03:10:18 +0100]
# 261872          localhost      127.0.0.1  [02/Mar/2014:03:10:18 +0100]
#
#                            request  status    size referer  \
# 261863  "GET /robots.txt HTTP/1.1"     301   301.0     "-"
# 261864  "GET /robots.txt HTTP/1.1"     301   304.0     "-"
# 261865            "GET / HTTP/1.1"     301   301.0     "-"
# 261866            "GET / HTTP/1.1"     200  7528.0     "-"
# 261867            "GET / HTTP/1.1"     301   304.0     "-"
# 261868            "GET / HTTP/1.1"     200  7528.0     "-"
# 261869           "HEAD / HTTP/1.1"     200     NaN     "-"
# 261870        "OPTIONS * HTTP/1.0"     200     NaN     "-"
# 261871        "OPTIONS * HTTP/1.0"     200     NaN     "-"
# 261872        "OPTIONS * HTTP/1.0"     200     NaN     "-"
#
#                                                user_agent
# 261863  "Mozilla/5.0 (compatible; YandexBot/3.0; +http...
# 261864  "Mozilla/5.0 (compatible; YandexBot/3.0; +http...
# 261865  "Mozilla/5.0 (compatible; YandexBot/3.0; +http...
# 261866  "Mozilla/5.0 (compatible; YandexBot/3.0; +http...
# 261867  "Mozilla/5.0 (compatible; YandexBot/3.0; +http...
# 261868  "Mozilla/5.0 (compatible; YandexBot/3.0; +http...
# 261869  "Mozilla/5.0+(compatible; UptimeRobot/2.0; htt...
# 261870               "Apache (internal dummy connection)"
# 261871               "Apache (internal dummy connection)"
# 261872               "Apache (internal dummy connection)"

# %%
# Clean dataset by eliminating ""

ds["request"] = ds["request"].str.extract("([^\"]+)")

ds["referer"] = ds["referer"].str.extract("([^\"]+)")

ds["user_agent"] = ds["user_agent"].str.extract("([^\"]+)")

ds.tail(5)
# Out:
#                    server             ip                          time  \
# 261868  www.akumenius.com   5.255.253.53  [02/Mar/2014:03:05:39 +0100]
# 261869  www.akumenius.com  74.86.158.107  [02/Mar/2014:03:09:52 +0100]
# 261870          localhost      127.0.0.1  [02/Mar/2014:03:10:18 +0100]
# 261871          localhost      127.0.0.1  [02/Mar/2014:03:10:18 +0100]
# 261872          localhost      127.0.0.1  [02/Mar/2014:03:10:18 +0100]
#
#                    request  status    size referer  \
# 261868      GET / HTTP/1.1     200  7528.0       -
# 261869     HEAD / HTTP/1.1     200     NaN       -
# 261870  OPTIONS * HTTP/1.0     200     NaN       -
# 261871  OPTIONS * HTTP/1.0     200     NaN       -
# 261872  OPTIONS * HTTP/1.0     200     NaN       -
#
#                                                user_agent
# 261868  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# 261869  Mozilla/5.0+(compatible; UptimeRobot/2.0; http...
# 261870                 Apache (internal dummy connection)
# 261871                 Apache (internal dummy connection)
# 261872                 Apache (internal dummy connection)

# %%
# To put IPs to use, import IPInfo Library; insert Token ID 

import ipinfo
handler = ipinfo.getHandler("6ec2f727d48c66")

# %%
# Convert IPs into a usable format

ipSize = ds.groupby("ip").size() # How many times an IP appears
series = ipSize.index # Different IPs, no duplicates

print(series)
# Out:
# Index(['101.199.108.59', '101.226.167.226', '107.178.37.48', '107.178.38.221',
#        '107.21.14.116', '107.6.95.11', '107.6.95.122', '107.6.95.13',
#        '107.6.95.16', '107.6.95.20',
#        ...
#        '95.62.55.142', '95.62.63.204', '95.63.1.210', '95.63.165.105',
#        '95.63.2.45', '95.63.234.126', '95.63.60.249', '96.242.31.129',
#        '98.137.206.41', '98.244.10.248'],
#       dtype='object', name='ip', length=2921)

# %%
# .getBatchDetails() gets all data from an array of IPs

details = handler.getBatchDetails(series)

# Conversion of IP info dictionary into a DataFrame:

dataBase = pd.DataFrame.from_dict(details, orient = 'index')
dataBase.head(10)
# Out:
#                               ip      city      region country  \
# 101.199.108.59    101.199.108.59   Beijing     Beijing      CN
# 101.226.167.226  101.226.167.226  Shanghai    Shanghai      CN
# 107.178.37.48      107.178.37.48  San Jose  California      US
# 107.178.38.221    107.178.38.221  San Jose  California      US
# 107.21.14.116      107.21.14.116   Ashburn    Virginia      US
# 107.6.95.11          107.6.95.11  San Jose  California      US
# 107.6.95.122        107.6.95.122  San Jose  California      US
# 107.6.95.13          107.6.95.13  San Jose  California      US
# 107.6.95.16          107.6.95.16  San Jose  California      US
# 107.6.95.20          107.6.95.20  San Jose  California      US
#
#                                loc             timezone   country_name  \
# 101.199.108.59    39.9075,116.3972        Asia/Shanghai          China
# 101.226.167.226   31.2222,121.4581        Asia/Shanghai          China
# 107.178.37.48    37.3394,-121.8950  America/Los_Angeles  United States
# 107.178.38.221   37.3394,-121.8950  America/Los_Angeles  United States
# 107.21.14.116     39.0437,-77.4875     America/New_York  United States
# 107.6.95.11      37.3394,-121.8950  America/Los_Angeles  United States
# 107.6.95.122     37.3394,-121.8950  America/Los_Angeles  United States
# 107.6.95.13      37.3394,-121.8950  America/Los_Angeles  United States
# 107.6.95.16      37.3394,-121.8950  America/Los_Angeles  United States
# 107.6.95.20      37.3394,-121.8950  America/Los_Angeles  United States
#
#                 latitude  longitude                           org  \
# 101.199.108.59   39.9075   116.3972                           NaN
# 101.226.167.226  31.2222   121.4581  AS4812 China Telecom (Group)
# 107.178.37.48    37.3394  -121.8950   AS174 Cogent Communications
# 107.178.38.221   37.3394  -121.8950   AS174 Cogent Communications
# 107.21.14.116    39.0437   -77.4875      AS14618 Amazon.com, Inc.
# 107.6.95.11      37.3394  -121.8950  AS29791 Internap Holding LLC
# 107.6.95.122     37.3394  -121.8950  AS29791 Internap Holding LLC
# 107.6.95.13      37.3394  -121.8950  AS29791 Internap Holding LLC
# 107.6.95.16      37.3394  -121.8950  AS29791 Internap Holding LLC
# 107.6.95.20      37.3394  -121.8950  AS29791 Internap Holding LLC
#
#                                                   hostname postal bogon
# 101.199.108.59                                         NaN    NaN   NaN
# 101.226.167.226                                        NaN    NaN   NaN
# 107.178.37.48               107-178-37-48.ip.cloudmosa.com  95103   NaN
# 107.178.38.221             107-178-38-221.ip.cloudmosa.com  95103   NaN
# 107.21.14.116    ec2-107-21-14-116.compute-1.amazonaws.com  20149   NaN
# 107.6.95.11                               secure.onavo.com  95103   NaN
# 107.6.95.122                              secure.onavo.com  95103   NaN
# 107.6.95.13                               secure.onavo.com  95103   NaN
# 107.6.95.16                               secure.onavo.com  95103   NaN
# 107.6.95.20                               secure.onavo.com  95103   NaN

# %%
# Add/mix frequency data

dataBase["frequency"] = ipSize
dataBase.head(5)
# Out:
#                               ip      city      region country  \
# 101.199.108.59    101.199.108.59   Beijing     Beijing      CN
# 101.226.167.226  101.226.167.226  Shanghai    Shanghai      CN
# 107.178.37.48      107.178.37.48  San Jose  California      US
# 107.178.38.221    107.178.38.221  San Jose  California      US
# 107.21.14.116      107.21.14.116   Ashburn    Virginia      US
#
#                                loc             timezone   country_name  \
# 101.199.108.59    39.9075,116.3972        Asia/Shanghai          China
# 101.226.167.226   31.2222,121.4581        Asia/Shanghai          China
# 107.178.37.48    37.3394,-121.8950  America/Los_Angeles  United States
# 107.178.38.221   37.3394,-121.8950  America/Los_Angeles  United States
# 107.21.14.116     39.0437,-77.4875     America/New_York  United States
#
#                 latitude  longitude                           org  \
# 101.199.108.59   39.9075   116.3972                           NaN
# 101.226.167.226  31.2222   121.4581  AS4812 China Telecom (Group)
# 107.178.37.48    37.3394  -121.8950   AS174 Cogent Communications
# 107.178.38.221   37.3394  -121.8950   AS174 Cogent Communications
# 107.21.14.116    39.0437   -77.4875      AS14618 Amazon.com, Inc.
#
#                                                   hostname postal bogon  \
# 101.199.108.59                                         NaN    NaN   NaN
# 101.226.167.226                                        NaN    NaN   NaN
# 107.178.37.48               107-178-37-48.ip.cloudmosa.com  95103   NaN
# 107.178.38.221             107-178-38-221.ip.cloudmosa.com  95103   NaN
# 107.21.14.116    ec2-107-21-14-116.compute-1.amazonaws.com  20149   NaN
#
#                  frequency
# 101.199.108.59          32
# 101.226.167.226          1
# 107.178.37.48          194
# 107.178.38.221         176
# 107.21.14.116            2

# %%
# Export to .csv so it can be visualised through Tableau:

dataBase.to_csv('IPs_data.csv')
